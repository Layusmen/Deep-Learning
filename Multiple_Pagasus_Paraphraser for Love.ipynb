# %% [markdown]
# <a href="https://colab.research.google.com/github/Layusmen/Deep-Learning/blob/Deep-Learning/Multiple_Pagasus_Paraphraser%20for%20Love.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
from transformers import PegasusForConditionalGeneration, PegasusTokenizer
model_name = 'tuner007/pegasus_paraphrase'
torch_device = 'cuda' if torch.cuda.is_available() else 'cpu'
tokenizer = PegasusTokenizer.from_pretrained(model_name)
model = PegasusForConditionalGeneration.from_pretrained(model_name).to(torch_device)
# Out:
# Downloading:   0%|          | 0.00/1.91M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/86.0 [00:00<?, ?B/s]

# %%
def get_response(input_text,num_return_sequences,num_beams):
  batch = tokenizer([input_text],truncation=True,padding='longest',max_length=500, return_tensors="pt").to(torch_device)
  translated = model.generate(**batch,max_length=60,num_beams=num_beams, num_return_sequences=num_return_sequences, temperature=1.5)
  tgt_text = tokenizer.batch_decode(translated, skip_special_tokens=True)
  return tgt_text

# %%
context = "Words cannot define how much I love you dear."
num_return_sequences=20
num_beams=20
get_response(context,num_return_sequences,num_beams)
# Out:
# ["Words can't tell how much I love you.",
#  "Words can't define how much I love you.",
#  "Words can't tell you how much I love you.",
#  "Words can't say how much I love you.",
#  "Words can't explain how much I love you.",
#  'Words cannot tell how much I love you.',
#  "Words can't determine how much I love you.",
#  "Words can't tell me how much I love you.",
#  "Words can't describe how much I love you.",
#  'Words cannot tell you how much I love you.',
#  "Words can't tell us how much I love you.",
#  'Words are not enough to define how much I love you.',
#  'Words cannot tell me how much I love you.',
#  'Words can not tell how much I love you.',
#  'Words cannot describe how much I love you.',
#  "Words can't tell how much I adore you.",
#  "Words can't define how much I adore you.",
#  'Words cannot say how much I love you.',
#  'Words cannot explain how much I love you.',
#  "Words can't tell you how much I adore you."]

# %%
model_name = 'tuner007/pegasus_paraphrase'
torch_device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
pip install sentencepiece
